# %% [markdown]
# # Review Assignment

# %% [markdown]
# First I'm going to attempt to use a shapefile, which I haven't done before starting by importing pandas and geopandas. I then ask geopandas to read the file. I'm going to start with the shp file and if that doesn't work try the xml, since it seems to have information.

# %%
import geopandas as gpd
df = gpd.read_file('../Data/CES4FinalShapefile.shp')
df.head()
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/conda/share/proj failed
#           Tract    ZIP         County    ApproxLoc  TotPop19    CIscore  \
# 0  6.083002e+09  93454  Santa Barbara  Santa Maria      4495  36.019653
# 1  6.083002e+09  93455  Santa Barbara  Santa Maria     13173  37.030667
# 2  6.083002e+09  93454  Santa Barbara  Santa Maria      2398  31.213140
# 3  6.083002e+09  93455  Santa Barbara       Orcutt      4496   6.639331
# 4  6.083002e+09  93455  Santa Barbara       Orcutt      4008  14.022852
#
#     CIscoreP     Ozone     OzoneP     PM2_5  ...  Elderly65  Hispanic  \
# 0  69.162885  0.034190  10.566273  7.567724  ...    12.5028   68.9210
# 1  70.637922  0.035217  11.561917  7.624775  ...     5.3519   78.6229
# 2  61.069087  0.034190  10.566273  7.548835  ...    12.8857   65.7214
# 3   5.988401  0.036244  13.615432  7.660570  ...    14.4128   22.9537
# 4  23.121533  0.036244  13.615432  7.663210  ...    18.8872   33.4082
#
# ...

# %% [markdown]
# To me, this showed that the file did work but that I'll definitely need to lessen the amount of data we're including. I next ran info with verbose = True to see if there was any null data to worry about. Since that is not the case, the decision will have to be made based on other factors.

# %%
# look at the data types, verbose = True shows us all the counts
df.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 67 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tract       8035 non-null   float64
#  1   ZIP         8035 non-null   int64
#  2   County      8035 non-null   object
#  3   ApproxLoc   8035 non-null   object
#  4   TotPop19    8035 non-null   int64
#  5   CIscore     8035 non-null   float64
#  6   CIscoreP    8035 non-null   float64
#  7   Ozone       8035 non-null   float64
#  8   OzoneP      8035 non-null   float64
#  9   PM2_5       8035 non-null   float64
#  10  PM2_5_P     8035 non-null   float64
#  11  DieselPM    8035 non-null   float64
#  12  DieselPM_P  8035 non-null   float64
#  13  Pesticide   8035 non-null   float64
#  14  PesticideP  8035 non-null   float64
#  15  Tox_Rel     8035 non-null   float64
#  16  Tox_Rel_P   8035 non-null   float64
#  17  Traffic     8035 non-null   float64
# ...

# %%
nonLA = for Los Angeles in County
# Out:
#   Cell In[22], line 1
#     nonLA = for Los Angeles in County
#             ^
# SyntaxError: invalid syntax

# %%
#Creating a column
df['highestpercent'] = maxcat

# %% [markdown]
# Next experimenting with the max function to see if I can add the highest percentage in each row and then remove the percentage columns. This I probably need to abandon as it doesn't seem to work (just getting nan, likely prior to getting to the max function.

# %%
maxcat = df.columns[df.loc[0].astype(str).str.endswith("p")].max()

# %% [markdown]
# *unclear might have worked but I keep getting errors with anyway I know how to test it based on head variable, potentially helps to add the column

# %%
df.head()
# Out:
#           Tract    ZIP         County    ApproxLoc  TotPop19    CIscore  \
# 0  6.083002e+09  93454  Santa Barbara  Santa Maria      4495  36.019653
# 1  6.083002e+09  93455  Santa Barbara  Santa Maria     13173  37.030667
# 2  6.083002e+09  93454  Santa Barbara  Santa Maria      2398  31.213140
# 3  6.083002e+09  93455  Santa Barbara       Orcutt      4496   6.639331
# 4  6.083002e+09  93455  Santa Barbara       Orcutt      4008  14.022852
#
#     CIscoreP     Ozone     OzoneP     PM2_5  ...  Hispanic    White  \
# 0  69.162885  0.034190  10.566273  7.567724  ...   68.9210  20.8899
# 1  70.637922  0.035217  11.561917  7.624775  ...   78.6229  13.2240
# 2  61.069087  0.034190  10.566273  7.548835  ...   65.7214  30.6088
# 3   5.988401  0.036244  13.615432  7.660570  ...   22.9537  69.1948
# 4  23.121533  0.036244  13.615432  7.663210  ...   33.4082  59.7804
#
#    AfricanAm  NativeAm  OtherMult    Shape_Leng    Shape_Area    AAPI  \
# ...

# %%
Whener

# %%
#starting this for columns to keep 
columns_to_keep = ['Tract'.astype('str'),
                   'County',
                   'TotPop19',
                   'CIscore',
                   'Ozone',
                   'PM2_5',
                   'DrinkWat',
                   'Tox_Rel',
                   'Traffic',
                   'PollBurd',
                   'Asthma']
# add it to a new dataframe
df2 = df[columns_to_keep]

# %% [markdown]
# Also will need to do all of the census tract adjusting, including for the first column FIPS I imagine? But also there is a geometry (which we imagine is a priority.

# %% [markdown]
# And limit to Los Angeles!

# %% [markdown]
# Find a socrata based open dataset
# Use the sodapy library and import it
# Conduct data exploration and analysis
# Create two or more plots using the plotly express library
# Create map visualization using plotly and/or the KeplerGL libraries
